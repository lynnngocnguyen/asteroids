# %%
# %matplotlib inline
import matplotlib.pylab as plt

import numpy as np
import pynbody as pb

import KeplerOrbit as ko

# %%
snap1 = pb.load ('asteroids_low.24680000')
snap = ko.orb_params(snap1)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/pynbody/snapshot/tipsy.py:130: RuntimeWarning: No readable param file in the run directory or parent directory: using defaults.
#   "No readable param file in the run directory or parent directory: using defaults.", RuntimeWarning)

# %%
snap['a']
# Out:
# SimArray([3.14436026, 3.06376529, 3.05398365, 3.17576722, 3.23316789,
#           3.24152456, 3.15371643, 3.12701907, 3.20322381, 3.2341876 ,
#           3.2000101 , 3.15493568, 3.2074883 , 3.13280874, 3.11442863,
#           3.27991112, 3.23842995, 3.19851208, 3.17144277, 3.23173863,
#           3.17380203, 3.16694642, 3.12865566, 3.25830552, 3.30962952,
#           3.19763987, 3.34315281, 3.12033033, 3.0967178 , 3.1640092 ,
#           3.24715684, 3.27090212, 3.20163654, 3.20438825, 3.14271928,
#           3.27203151, 3.05573824, 3.26602739, 3.20993828, 3.16069398,
#           3.12006337, 3.16701554, 3.06258814, 3.21356565, 3.29199698,
#           3.20634707, 3.24060614, 3.06040317, 3.20422732, 3.24410592,
#           3.13436377, 3.068839  , 3.15140953, 3.26600374, 3.28728151,
#           3.262887  , 3.11411687, 3.16745479, 3.07200982, 3.15587344,
#           3.29808029, 3.05974766, 3.14008826, 3.15868935, 3.06782945,
# ...

# %%
snap['e']
# Out:
# SimArray([0.00547446, 0.01852036, 0.00934151, 0.00133274, 0.0097356 ,
#           0.01161676, 0.00936354, 0.00836074, 0.01435143, 0.00077459,
#           0.0081799 , 0.00715811, 0.00911658, 0.00099761, 0.00511429,
#           0.00337037, 0.00789155, 0.00888059, 0.00340104, 0.01844802,
#           0.00107498, 0.00099909, 0.01149933, 0.01661271, 0.0163175 ,
#           0.00960001, 0.01560322, 0.00194372, 0.00036372, 0.00048126,
#           0.01063418, 0.00194243, 0.00508019, 0.0118025 , 0.0032397 ,
#           0.01618311, 0.02201985, 0.01364395, 0.0035135 , 0.0021685 ,
#           0.00523737, 0.00224926, 0.00869475, 0.01397548, 0.01782139,
#           0.00777289, 0.01038326, 0.01637843, 0.01083204, 0.008499  ,
#           0.00591253, 0.00352697, 0.00027981, 0.00639099, 0.00372044,
#           0.0099494 , 0.00741097, 0.00205331, 0.0080817 , 0.00235892,
#           0.0323196 , 0.01495359, 0.00304802, 0.00226411, 0.01767465,
# ...

# %%
xpos = snap['pos'][:,0]
ypos = snap['pos'][:,1]

# %%
plt.scatter(xpos,ypos)

# %%
snap['vel']
# Out:
# SimArray([[-4.61078167e-01, -3.21310490e-01,  3.36158229e-03],
#           [ 5.08590937e-01, -2.80706674e-01,  3.56491911e-03],
#           [-3.63646895e-01, -4.43303794e-01, -3.79781355e-03],
#           [-5.34675837e-01,  1.67932227e-01, -1.78509799e-03],
#           [-5.27404606e-01,  1.78924367e-01, -2.20691189e-04],
#           [-1.10661738e-01,  5.38455784e-01, -3.24286404e-03],
#           [-5.60356081e-01, -2.56111789e-02,  7.67812482e-04],
#           [-3.29033971e-01,  4.54359174e-01, -4.25569061e-03],
#           [ 4.60283995e-01, -3.07941318e-01, -3.45423399e-03],
#           [-3.43441755e-01,  4.37577665e-01, -2.66132690e-03],
#           [ 5.49814045e-01, -1.10457554e-01,  1.30903081e-03],
#           [ 4.23169851e-01,  3.74691933e-01,  7.62962911e-04],
#           [-3.18261348e-02,  5.60724199e-01, -3.19037423e-03],
#           [-2.95639962e-01, -4.81533796e-01, -9.41519393e-04],
#           [ 2.06995070e-01,  5.25906503e-01,  5.00977831e-03],
# ...

# %%
snap['mass']
# Out:
# SimArray([3.01738717e-10, 1.50869359e-10, 1.50869359e-10, 1.50869359e-10,
#           4.52608062e-10, 1.50869359e-10, 3.01738717e-10, 1.50869359e-10,
#           6.03477435e-10, 1.50869359e-10, 3.01738717e-10, 6.03477435e-10,
#           6.03477435e-10, 9.50476942e-09, 1.50869359e-10, 7.54346807e-10,
#           1.50869359e-10, 1.50869359e-10, 1.50869359e-10, 1.50869359e-10,
#           1.50869359e-10, 3.01738717e-10, 1.50869359e-10, 1.50869359e-10,
#           1.50869359e-10, 7.54346807e-10, 3.01738717e-10, 4.52608062e-10,
#           5.58216628e-09, 1.50869359e-10, 3.01738717e-10, 6.48738263e-09,
#           1.50869359e-10, 1.50869359e-10, 1.50869359e-10, 1.50869359e-10,
#           3.01738717e-10, 4.07347267e-09, 3.01738717e-10, 1.50869359e-10,
#           1.50869359e-10, 1.50869359e-10, 3.01738717e-10, 3.01738717e-10,
#           1.50869359e-10, 4.52608062e-10, 1.50869359e-10, 1.50869359e-10,
#           1.50869359e-10, 3.01738717e-10, 1.50869359e-10, 1.35782419e-09,
# ...

# %%
snap2 = pb.load ('asteroids_low.4150000')
snap = ko.orb_params(snap)
snap['a']
snap['e']
xpos = snap['pos'][:,0]
ypos = snap['pos'][:,1]
plt.scatter(xpos,ypos)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/KeplerOrbit/KeplerOrbit.py:71: RuntimeWarning: invalid value encountered in arccos
#   E = np.arccos((e + np.cos(theta)) / (1 + e * np.cos(theta)))

# %%
snap3 = pb.load ('asteroids_low.8670000')
snap = ko.orb_params(snap)
snap['a']
snap['e']
xpos = snap['pos'][:,0]
ypos = snap['pos'][:,1]
plt.scatter(xpos,ypos)

# %%
a = snap['a']
e = snap['e']
# Out:
# SimArray([-3.83262057e-10, -2.33958388e-10, -4.69792443e-10,
#           -2.86131027e-10, -3.74759551e-10, -2.42946131e-10,
#           -2.41425701e-07, -2.42959351e-10, -1.47481245e-08,
#           -1.72677906e-09, -7.54269738e-10, -1.40519405e-08,
#           -4.06882441e-10, -2.32513803e-09, -5.10361136e-09,
#           -3.11415641e-09, -3.01565668e-10, -2.34415994e-10,
#           -2.33072662e-10, -8.06687626e-10, -2.67096979e-10,
#           -2.74991100e-08, -9.98259964e-10, -1.57809132e-08,
#           -3.29132597e-08, -5.01202997e-10, -4.39328473e-09,
#           -3.19430186e-10, -2.02978159e-07, -5.23241571e-09,
#           -2.38714426e-10, -2.55248110e-09, -2.75576818e-09,
#           -3.74566821e-10, -1.31551964e-09, -3.33616539e-09,
#           -3.59881919e-10, -5.77111128e-10, -4.10209418e-10,
#           -2.51461644e-09, -1.76938270e-09, -2.00897818e-09,
#           -2.70465052e-10, -4.90783252e-10, -1.39493389e-09,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a
# Out:
# SimArray([-3.83262057e-10, -2.33958388e-10, -4.69792443e-10,
#           -2.86131027e-10, -3.74759551e-10, -2.42946131e-10,
#           -2.41425701e-07, -2.42959351e-10, -1.47481245e-08,
#           -1.72677906e-09, -7.54269738e-10, -1.40519405e-08,
#           -4.06882441e-10, -2.32513803e-09, -5.10361136e-09,
#           -3.11415641e-09, -3.01565668e-10, -2.34415994e-10,
#           -2.33072662e-10, -8.06687626e-10, -2.67096979e-10,
#           -2.74991100e-08, -9.98259964e-10, -1.57809132e-08,
#           -3.29132597e-08, -5.01202997e-10, -4.39328473e-09,
#           -3.19430186e-10, -2.02978159e-07, -5.23241571e-09,
#           -2.38714426e-10, -2.55248110e-09, -2.75576818e-09,
#           -3.74566821e-10, -1.31551964e-09, -3.33616539e-09,
#           -3.59881919e-10, -5.77111128e-10, -4.10209418e-10,
#           -2.51461644e-09, -1.76938270e-09, -2.00897818e-09,
#           -2.70465052e-10, -4.90783252e-10, -1.39493389e-09,
# ...

# %%
x = np.linspace(0, 1, 400) #how do i make the xy smaller axis
y = np.sin(x ** 2)

# %%
snap1= pb.load('asteroids_low.24680000')
snap1 = ko.orb_params(snap1)
snap2= pb.load('asteroids_low.4150000')
snap2 = ko.orb_params(snap2)
snap3= pb.load('asteroids_low.8670000')
snap3 = ko.orb_params(snap3)

# %%
idx = np.argsort(snap3['mass'])
e_mass = snap3['e'][idx][-5:]
a_mass = snap3['a'][idx][-5:]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize= (8,8), sharey = True , sharex = True)
fig.suptitle('N=4000')
ax1.scatter(snap1['a'], snap1['e'], s = 5)
ax2.scatter(snap2['a'],snap2['e'], s = 5)
ax3.scatter(snap3['a'], snap3['e'], s = 5)
ax3.scatter(a_mass, e_mass, s = 50)
#ax1.set_ylim(0,0.03)
ax1.set_xlim(3.0,3.4)
ax3.set_xlabel('SemiMajorAxis AU')
ax2.set_ylabel('Eccentricity')

xerror= 0.5

ax3.errorbar(a_mass , e_mass, xerr=xerror)
plt.tight_layout()
#this is my error bar... idk how to fix it

# %%
idx = np.argsort(snap3['mass'])

# %%
e_mass = snap3['e'][idx][-5:]
a_mass = snap3['a'][idx][-5:]

# %%
fig, ax = plt.subplots( figsize= (8,8), sharey = True , sharex = True)
ax.hist(snap3['e'])
# Out:
# (array([81., 85., 97., 72., 69., 51., 29., 17., 16.,  2.]),
#  SimArray([0.00012795, 0.00200432, 0.0038807 , 0.00575707, 0.00763344,
#            0.00950982, 0.01138619, 0.01326257, 0.01513894, 0.01701531,
#            0.01889169]),
#  <a list of 10 Patch objects>)

# %%
logbins = np.logspace(np.log10(np.min(snap3['e'])) , np.log10(np.max(snap3['e'])))
hist, bins = np.histogram(snap3['e'] , bins = logbins)
bins = 0.5 * (bins[1:] + bins[:-1])
fig, ax = plt.subplots( figsize= (8,8), sharey = True , sharex = True)
ax.plot(bins , hist , linestyle='steps-mid')
ax.set_xscale('log')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   """

# %%
fig, ax = plt.subplots( figsize= (8,8), sharey = True , sharex = True)
ax.hist(snap2['e'])
# Out:
# (array([ 80., 145., 110., 132.,  92.,  49.,  33.,  13.,   7.,   5.]),
#  SimArray([9.21248154e-05, 1.73472282e-03, 3.37732083e-03, 5.01991883e-03,
#            6.66251684e-03, 8.30511484e-03, 9.94771285e-03, 1.15903109e-02,
#            1.32329089e-02, 1.48755069e-02, 1.65181049e-02]),
#  <a list of 10 Patch objects>)

# %%
logbins = np.logspace(np.log10(np.min(snap2['e'])) , np.log10(np.max(snap2['e'])))
hist, bins = np.histogram(snap2['e'] , bins = logbins)
bins = 0.5 * (bins[1:] + bins[:-1])
fig, ax = plt.subplots( figsize= (8,8), sharey = True , sharex = True)
ax.plot(bins , hist , linestyle='steps-mid')
ax.set_xscale('log')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   """

# %%
fig, ax = plt.subplots( figsize= (8,8), sharey = True , sharex = True)
ax.hist(snap1['e'])
# Out:
# (array([69., 74., 55., 44., 31., 25.,  9.,  9.,  1.,  1.]),
#  SimArray([0.00027981, 0.00348379, 0.00668776, 0.00989174, 0.01309572,
#            0.0162997 , 0.01950368, 0.02270766, 0.02591164, 0.02911562,
#            0.0323196 ]),
#  <a list of 10 Patch objects>)

# %%
logbins = np.logspace(np.log10(np.min(snap1['e'])) , np.log10(np.max(snap1['e'])))
hist, bins = np.histogram(snap1['e'] , bins = logbins)
bins = 0.5 * (bins[1:] + bins[:-1])
fig, ax = plt.subplots( figsize= (8,8), sharey = True , sharex = True)
ax.plot(bins , hist , linestyle='steps-mid')
ax.set_xscale('log')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   """

# %%
import pylab
import numpy

x = numpy.linspace(0,100,10) 
y = numpy.sin(x)/x 


pylab.plot(snap1['a'], snap1['e']) # sin(x)/x
pylab.plot(snap2['a'],snap2['e'], 'co') # same function with cyan dots
pylab.plot(snap3['a'], 2* snap3['e'], snap3['a'], 3* snap3['e']) 
pylab.show()
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %%
import pylab
import numpy

x = numpy.linspace(-15,15,100) # 100 linearly spaced numbers
y = numpy.sin(x)/x # computing the values of sin(x)/x

# compose plot
pylab.plot(x,y) # sin(x)/x
pylab.plot(x,y,'co') # same function with cyan dots
pylab.plot(x,2*y,x,3*y) # 2*sin(x)/x and 3*sin(x)/x
pylab.show() # show the plot

#tried to do it using test.ic but not sure, opened up the file and got a bunch of numbers

# %%
snap1 = pb.load ('../makePlICs/test.ic')
snap = ko.orb_params(snap1)
m_pl = np.min(snap['mass'])
M_star = 1
r_h = (2*m_pl/(3*M_star))**(1/3)
snap['e_h'] = snap['e']/ r_h
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-27-66150d63a0fd> in <module>
# ----> 1 snap1 = pb.load ('../makePlICs/test.ic')
#       2 snap = ko.orb_params(snap1)
#       3 m_pl = np.min(snap['mass'])
#       4 M_star = 1
#       5 r_h = (2*m_pl/(3*M_star))**(1/3)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pynbody/snapshot/__init__.py in load(filename, *args, **kwargs)
#    1985
#    1986     raise IOError(
# -> 1987         "File %r: format not understood or does not exist" % filename)
#    1988
#    1989 def new(n_particles=0, order=None, **families):
#
# OSError: File '../makePlICs/test.ic': format not understood or does not exist

# %%
logbins = np.logspace(np.log10(np.min(snap['e_h'])) , np.log10(np.max(snap['e_h'])))
hist, bins = np.histogram(snap['e_h'] , bins = logbins , normed = True)
bins = 0.5 * (bins[1:] + bins[:-1])
fig, ax = plt.subplots( figsize= (8,8), sharey = True , sharex = True)
ax.plot(bins , hist , linestyle='steps-mid')
ax.set_xscale('log')
sigma = 7
x = logbins 
y = x/(sigma)**2 *(numpy.exp(-x**2 / (2* sigma**2))) 
a = 1 / numpy.trapz(y,x)
pylab.plot(x,a*y) 
print(a)
